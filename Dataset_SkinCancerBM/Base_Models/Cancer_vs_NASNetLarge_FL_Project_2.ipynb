# %% [markdown]
# ## Load Pre Processed Dataset

# %%
import zipfile
import pandas as pd

with zipfile.ZipFile("/content/drive/MyDrive/Student/Mohit/Dataset/Skin_Cancer_Malignant_vs_Benign/archive.zip", 'r') as zip_ref:
    zip_ref.extractall("/content")


train_load_path = '/content/drive/MyDrive/Student/Mohit/Dataset/Federated_Learning_Project_2/Processed_CSV/train_df.csv'
test_load_path = '/content/drive/MyDrive/Student/Mohit/Dataset/Federated_Learning_Project_2/Processed_CSV/test_df.csv'
val_load_path = '/content/drive/MyDrive/Student/Mohit/Dataset/Federated_Learning_Project_2/Processed_CSV/val_df.csv'

# Loading dataframes from the CSV files
train_df = pd.read_csv(train_load_path)
test_df = pd.read_csv(test_load_path)
val_df = pd.read_csv(val_load_path)

print("Train DataFrame:")
display(train_df)

print("\nTest DataFrame:")
display(test_df)

print("\nValidation DataFrame:")
display(val_df)
# Out:
# Train DataFrame:
#                                    file_path      label
# 0         /content/data/train/benign/183.jpg     benign
# 1         /content/data/train/benign/852.jpg     benign
# 2        /content/data/train/benign/1515.jpg     benign
# 3         /content/data/train/benign/807.jpg     benign
# 4        /content/data/train/benign/1580.jpg     benign
# ...                                      ...        ...
# 2632   /content/data/train/malignant/685.jpg  malignant
# 2633  /content/data/train/malignant/1481.jpg  malignant
# 2634  /content/data/train/malignant/1247.jpg  malignant
# 2635   /content/data/train/malignant/550.jpg  malignant
# 2636   /content/data/train/malignant/245.jpg  malignant
#
# [2637 rows x 2 columns]
# Test DataFrame:
#                                  file_path      label
# 0        /content/data/test/benign/878.jpg     benign
# 1    /content/data/test/malignant/1026.jpg  malignant
# 2    /content/data/test/malignant/1499.jpg  malignant
# 3       /content/data/test/benign/1350.jpg     benign
# 4        /content/data/test/benign/894.jpg     benign
# ..                                     ...        ...
# 325      /content/data/test/benign/626.jpg     benign
# 326      /content/data/test/benign/824.jpg     benign
# 327     /content/data/test/benign/1412.jpg     benign
# 328   /content/data/test/malignant/237.jpg  malignant
# 329      /content/data/test/benign/454.jpg     benign
#
# [330 rows x 2 columns]
# Validation DataFrame:
#                                  file_path      label
# 0     /content/data/test/malignant/317.jpg  malignant
# 1    /content/data/test/malignant/1074.jpg  malignant
# 2       /content/data/test/benign/1655.jpg     benign
# 3     /content/data/test/malignant/706.jpg  malignant
# 4       /content/data/test/benign/1479.jpg     benign
# ..                                     ...        ...
# 325  /content/data/test/malignant/1333.jpg  malignant
# 326      /content/data/test/benign/317.jpg     benign
# 327     /content/data/test/benign/1208.jpg     benign
# 328  /content/data/test/malignant/1056.jpg  malignant
# 329  /content/data/test/malignant/1038.jpg  malignant
#
# [330 rows x 2 columns]

# %% [markdown]
# ## Now Prepare Images

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

df_train = train_df
df_test = test_df
df_val = val_df

label_encoder = LabelEncoder()
df_train['label'] = label_encoder.fit_transform(df_train['label'])
df_test['label'] = label_encoder.transform(df_test['label'])
df_val['label'] = label_encoder.transform(df_val['label'])

print("Class mapping:")
for index, class_label in enumerate(label_encoder.classes_):
    print(f"{index}: {class_label}")

print("Train set class distribution:")
print(df_train['label'].value_counts())
print("\nTest set class distribution:")
print(df_test['label'].value_counts())
print("\nVal set class distribution:")
print(df_val['label'].value_counts())

df_train['label'] = df_train['label'].astype(str)
df_test['label'] = df_test['label'].astype(str)
df_val['label'] = df_val['label'].astype(str)

train_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg19.preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg19.preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg19.preprocess_input)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=df_train,
    x_col='file_path',
    y_col='label',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    seed=42,
    shuffle=True
)

val_generator = val_datagen.flow_from_dataframe(
    dataframe=df_val,
    x_col='file_path',
    y_col='label',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=df_test,
    x_col='file_path',
    y_col='label',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Class mapping:
# 0: benign
# 1: malignant
# Train set class distribution:
# label
# 0    1440
# 1    1197
# Name: count, dtype: int64
#
# Test set class distribution:
# label
# 1    166
# 0    164
# Name: count, dtype: int64
#
# Val set class distribution:
# label
# 0    196
# 1    134
# Name: count, dtype: int64
# Found 2637 validated image filenames belonging to 2 classes.
# Found 330 validated image filenames belonging to 2 classes.
# Found 330 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Now Creating Model NASNetLarge

# %%
import tensorflow as tf
import time

# Load base model (NASNetLarge without top layers)
base_model = tf.keras.applications.NASNetLarge(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)
base_model.trainable = False  # Freeze base layers

# Input layer
inputs = tf.keras.Input(shape=(224, 224, 3))

# Pass through base model
x = base_model(inputs, training=False)

# Custom classification head
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
outputs = tf.keras.layers.Dense(len(label_encoder.classes_), activation='softmax')(x)

# Create model
model = tf.keras.Model(inputs, outputs)

# Compile
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ nasnet_large (Functional)       │ (None, 7, 7, 4032)     │    84,916,818 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 197568)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    50,577,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 135,494,996 (516.87 MB)
#  Trainable params: 50,578,178 (192.94 MB)
#  Non-trainable params: 84,916,818 (323.93 MB)

# %%
# Early stopping callback
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Track training time
start_time = time.time()

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=[early_stop]
)

end_time = time.time()
elapsed = end_time - start_time
mins, secs = divmod(elapsed, 60)
print(f"\nTotal training time: {int(mins)} min {int(secs)} sec")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.5861 - loss: 4.8688 - val_accuracy: 0.7364 - val_loss: 0.5660
# Epoch 2/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 350ms/step - accuracy: 0.7085 - loss: 0.6011 - val_accuracy: 0.7515 - val_loss: 0.5320
# Epoch 3/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 353ms/step - accuracy: 0.7359 - loss: 0.5223 - val_accuracy: 0.7212 - val_loss: 0.5197
# Epoch 4/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 358ms/step - accuracy: 0.7740 - loss: 0.4895 - val_accuracy: 0.7818 - val_loss: 0.4821
# Epoch 5/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 0.7678 - loss: 0.4706 - val_accuracy: 0.7788 - val_loss: 0.4638
# Epoch 6/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 354ms/step - accuracy: 0.7672 - loss: 0.4499 - val_accuracy: 0.7364 - val_loss: 0.5567
# Epoch 7/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 365ms/step - accuracy: 0.8034 - loss: 0.3979 - val_accuracy: 0.7818 - val_loss: 0.4349
# Epoch 8/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 355ms/step - accuracy: 0.8162 - loss: 0.3738 - val_accuracy: 0.7818 - val_loss: 0.4438
# Epoch 9/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 359ms/step - accuracy: 0.8303 - loss: 0.3461 - val_accuracy: 0.7758 - val_loss: 0.4676
# Epoch 10/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 359ms/step - accuracy: 0.8458 - loss: 0.3363 - val_accuracy: 0.7636 - val_loss: 0.4609
# Epoch 11/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 360ms/step - accuracy: 0.8354 - loss: 0.3488 - val_accuracy: 0.8091 - val_loss: 0.4537
# Epoch 12/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 361ms/step - accuracy: 0.8644 - loss: 0.3018 - val_accuracy: 0.7727 - val_loss: 0.4449
# Epoch 13/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 371ms/step - accuracy: 0.8623 - loss: 0.2845 - val_accuracy: 0.8152 - val_loss: 0.4329
# Epoch 14/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 361ms/step - accuracy: 0.8693 - loss: 0.2746 - val_accuracy: 0.8273 - val_loss: 0.4381
# Epoch 15/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 385ms/step - accuracy: 0.8684 - loss: 0.2662 - val_accuracy: 0.8000 - val_loss: 0.4528
# Epoch 16/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 0.8551 - loss: 0.2734 - val_accuracy: 0.7909 - val_loss: 0.4682
# Epoch 17/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 0.8767 - loss: 0.2572 - val_accuracy: 0.8121 - val_loss: 0.4445
# Epoch 18/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 363ms/step - accuracy: 0.8788 - loss: 0.2462 - val_accuracy: 0.8152 - val_loss: 0.4613
# Epoch 19/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 0.8905 - loss: 0.2273 - val_accuracy: 0.7848 - val_loss: 0.4736
# Epoch 20/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 363ms/step - accuracy: 0.8872 - loss: 0.2259 - val_accuracy: 0.7939 - val_loss: 0.4798
# Epoch 21/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 364ms/step - accuracy: 0.8799 - loss: 0.2316 - val_accuracy: 0.7727 - val_loss: 0.4977
# Epoch 22/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 361ms/step - accuracy: 0.9029 - loss: 0.2035 - val_accuracy: 0.8030 - val_loss: 0.4605
# Epoch 23/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 360ms/step - accuracy: 0.8998 - loss: 0.2139 - val_accuracy: 0.7848 - val_loss: 0.5473
#
# Total training time: 14 min 14 sec

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test Set

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import time

# Evaluate on test set
start_time = time.time()
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
end_time = time.time()
test_time = end_time - start_time

print(f"\nTest Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Evaluation Time: {test_time:.2f} seconds")

# Predict labels
y_pred_probs = model.predict(test_generator, verbose=0)
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = test_generator.classes

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
class_names = list(label_encoder.classes_)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Optional: classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Test Accuracy: 0.7788
# Test Loss: 0.5709
# Test Evaluation Time: 3.46 seconds
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.76      0.82      0.79       164
#    malignant       0.80      0.74      0.77       166
#
#     accuracy                           0.78       330
#    macro avg       0.78      0.78      0.78       330
# weighted avg       0.78      0.78      0.78       330

# %% [markdown]
# ### Val Set

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import time

# Evaluate on test set
start_time = time.time()
test_loss, test_acc = model.evaluate(val_generator, verbose=0)
end_time = time.time()
test_time = end_time - start_time

print(f"\nVal Accuracy: {test_acc:.4f}")
print(f"Val Loss: {test_loss:.4f}")
print(f"Val Evaluation Time: {test_time:.2f} seconds")

# Predict labels
y_pred_probs = model.predict(val_generator, verbose=0)
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = val_generator.classes

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
class_names = list(label_encoder.classes_)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Optional: classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Val Accuracy: 0.8152
# Val Loss: 0.4329
# Val Evaluation Time: 3.36 seconds
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.85      0.84      0.84       196
#    malignant       0.77      0.78      0.77       134
#
#     accuracy                           0.82       330
#    macro avg       0.81      0.81      0.81       330
# weighted avg       0.82      0.82      0.82       330

# %% [markdown]
# ## Finally saving the model

# %%
import shutil

model.save('NASNetLarge_model.keras')

destination = '/content/drive/MyDrive/Student/Mohit/Model/Federated_Learning_Project_2/Base_Models/NASNetLarge/NASNetLarge_model.keras'
shutil.move('NASNetLarge_model.keras', destination)

print(f'Model saved to {destination}')
# Out:
# Model saved to /content/drive/MyDrive/Student/Mohit/Model/Federated_Learning_Project_2/Base_Models/NASNetLarge/NASNetLarge_model.keras

# %% [markdown]
# ## Load The model (If need)

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/Student/Mohit/Model/Federated_Learning_Project_2/Base_Models/NASNetLarge/NASNetLarge_model.keras')
